# %% [markdown]
# SELECT SUM(purchasedItemCount)
# FROM receipts
# WHERE rewardsReceiptStatus = 'Finished';
#
# SELECT SUM(purchasedItemCount)
# FROM receipts
# WHERE rewardsReceiptStatus = 'Rejected'

# %%
import json
import pandas as pd
receipts = pd.read_json('receipts.json',lines = True)
receipts
# Out:
#                                        _id  bonusPointsEarned  \
# 0     {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1     {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2     {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 3     {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
# 4     {'$oid': '5ff1e1d20a7214ada1000561'}                5.0
# ...                                    ...                ...
# 1114  {'$oid': '603cc0630a720fde100003e6'}               25.0
# 1115  {'$oid': '603d0b710a720fde1000042a'}                NaN
# 1116  {'$oid': '603cf5290a720fde10000413'}                NaN
# 1117  {'$oid': '603ce7100a7217c72c000405'}               25.0
# 1118  {'$oid': '603c4fea0a7217c72c000389'}                NaN
#
#                                 bonusPointsEarnedReason  \
# 0     Receipt number 2 completed, bonus point schedu...
# 1     Receipt number 5 completed, bonus point schedu...
# ...

# %%
#handling missing data
receipts.isnull()
# Out:
#         _id  bonusPointsEarned  bonusPointsEarnedReason  createDate  \
# 0     False              False                    False       False
# 1     False              False                    False       False
# 2     False              False                    False       False
# 3     False              False                    False       False
# 4     False              False                    False       False
# ...     ...                ...                      ...         ...
# 1114  False              False                    False       False
# 1115  False               True                     True       False
# 1116  False               True                     True       False
# 1117  False              False                    False       False
# 1118  False               True                     True       False
#
#       dateScanned  finishedDate  modifyDate  pointsAwardedDate  pointsEarned  \
# ...

# %%
brands = pd.read_json('brands.json',lines = True)
brands
# Out:
#                                        _id       barcode            category  \
# 0     {'$oid': '601ac115be37ce2ead437551'}  511111019862              Baking
# 1     {'$oid': '601c5460be37ce2ead43755f'}  511111519928           Beverages
# 2     {'$oid': '601ac142be37ce2ead43755d'}  511111819905              Baking
# 3     {'$oid': '601ac142be37ce2ead43755a'}  511111519874              Baking
# 4     {'$oid': '601ac142be37ce2ead43755e'}  511111319917      Candy & Sweets
# ...                                    ...           ...                 ...
# 1162  {'$oid': '5f77274dbe37ce6b592e90c0'}  511111116752              Baking
# 1163  {'$oid': '5dc1fca91dda2c0ad7da64ae'}  511111706328  Breakfast & Cereal
# 1164  {'$oid': '5f494c6e04db711dd8fe87e7'}  511111416173      Candy & Sweets
# 1165  {'$oid': '5a021611e4b00efe02b02a57'}  511111400608             Grocery
# 1166  {'$oid': '6026d757be37ce6369301468'}  511111019930              Baking
#
# ...

# %%
#handling missing data
brands.isnull()
# Out:
#         _id  barcode  category  categoryCode    cpg   name  topBrand  \
# 0     False    False     False         False  False  False     False
# 1     False    False     False         False  False  False     False
# 2     False    False     False         False  False  False     False
# 3     False    False     False         False  False  False     False
# 4     False    False     False         False  False  False     False
# ...     ...      ...       ...           ...    ...    ...       ...
# 1162  False    False     False         False  False  False      True
# 1163  False    False     False          True  False  False      True
# 1164  False    False     False         False  False  False      True
# 1165  False    False     False          True  False  False     False
# 1166  False    False     False         False  False  False     False
#
#       brandCode
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# ...

# %%
users = pd.read_json('users.json',lines = True)
users
# Out:
#                                       _id  active               createdDate  \
# 0    {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 1    {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 2    {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 3    {'$oid': '5ff1e1eacfcf6c399c274ae6'}    True  {'$date': 1609687530554}
# 4    {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# ..                                    ...     ...                       ...
# 490  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
# 491  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
# 492  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
# 493  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
# 494  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
#
# ...

# %%
users.describe ()
# Out:
#                                          _id active               createdDate  \
# count                                    495    495                       495
# unique                                   212      2                       212
# top     {'$oid': '54943462e4b07e684157a532'}   True  {'$date': 1418998882381}
# freq                                      20    494                        20
#
#                        lastLogin      role signUpSource state
# count                        433       495          447   439
# unique                       172         2            2     8
# top     {'$date': 1614379156799}  consumer        Email    WI
# freq                          20       413          443   396

# %%
#handling missing data
users['_id'].isnull().sum()
# Out:
# 0

# %%
users['active'].isnull().sum()
# Out:
# 0

# %%
users['state'].isnull().sum()
# Out:
# 56

# %%
users['role'].isnull().sum()
# Out:
# 0

# %%
users['createdDate'].isnull().sum()
# Out:
# 0

# %%
users['signUpSource'].isnull().sum()
# Out:
# 48

# %%
users['lastLogin'].isnull().sum()
# Out:
# 62

# %% [markdown]
# From the result above, we can tell that there are missing values in all tables. For example, users table has missing value issue existing in 'state','signUpSource', and 'lastLogin' columns. The other obvious data quality issue is the  data format issue. Based on my observation, any columns involving with date are hard to interpret the date information .

# %% [markdown]
# ### Fourth: Communicate with Stakeholders
# #### What questions do you have about the data?
# My question will be what is the stakeholders' goal, like what relationship they want to know from the data. What is their business goal. Do you want to know the consumer behavior from the data? Do you want to know about the profit aspect of the data?
# #### How did you discover the data quality issues?
# I firstly read through the data to have a basic understanding about what it's about. Based on my observation, it is easy to tell that there is some manual data entry error. Then, I used "descibed" function to get the summary statistics about the table. From this, I can get the missing value counts.
# #### What do you need to know to resolve the data quality issues?
# For the missing value, I am wondering if the company wants me to drop the missing value or impute the missing value. If I do the imputation, what criteria the company wants me to use. For the date formating, I want to know how they format the date value when they enter the value.
# #### What other information would you need to help you optimize the data assets you're trying to create?
# I need the profit that the company earned from each scan. I need to know the corresponding barcode from both receipts and brand data. I also need the brand id corresponding to the user table.
# #### What performance and scaling concerns do you anticipate in production and how do you plan to address them?
# I think the concern that I have is there is not that many data, so the performance maybe biased after I drop all the null data.
